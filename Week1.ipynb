# %% [markdown]
# <a href="https://colab.research.google.com/github/meryymarta/DataMining/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import numpy as np
from sklearn import tree

iris = load_iris() # variable iris diambil dari load iris
test_index = [0, 50, 100] # 0,50, 100 batasan sebagai ujicoba

print(iris.feature_names)
print(iris.target_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']
